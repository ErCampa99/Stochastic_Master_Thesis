# %%
import importlib
import quantum_function
importlib.reload(quantum_function)

from quantum_function import *
from IPython.display import display, Markdown

# %%
# --- SAFETY SWITCH: esce subito se non abiliti esplicitamente ---
RUN_THIS_CELL = True   # metti True solo quando vuoi davvero eseguire

if not RUN_THIS_CELL:
    display(Markdown("Cell locked. Set `RUN_THIS_CELL = True` to run"))
    raise SystemExit



plt.rcParams["text.usetex"] = True
plt.rcParams.update({
    "mathtext.fontset": "cm",      # font simile a LaTeX
    "font.family": "serif",
    "font.size": 14,
    "axes.unicode_minus": False
})

# %%
#PARAMETERS!

gamma = 1        # Atom decay rate
T_1 = 1 / gamma  # time constant for the decay

times = np.array(np.arange(0, 10*T_1, 0.01*T_1)) 

my_label_eta = ["1", "0.9", "0.7", "0.5", "0.3"] 

my_eta = [1, 0.9, 0.7, 0.5, 0.3] #etas for the homodyne detection

css_theta = np.pi/5  # angle for the CSS state
state = css_2(css_theta, phi=0)

my_opts_dict = {
    "keep_runs_results": False,
    #"map":"parallel",
    #"normalize_output" : False,
    #"store_final_state" : False,
    #"store_states": False,
    #"store_measurement": False,
    #"progress_bar": "Enhanced",
    "num_cpus": os.cpu_count()-1,
    }

columns_label = [
                #"Energy",
                 "Conc",
                 #"Xi2_KU",
                 #"F_phi_plus",
                 #"F_phi_minus",
                 #"F_psi_plus",
                 #"F_psi_minus"
            ]

label_graph_column = {
    #"Energy": r"Energy",
    "Conc": r"$\overline{\mathcal{C}}$",
    #"Xi2_KU": r"$\xi^2_{KU}$",
    #"F_phi_plus": r"Fidelity $|\Phi^+\rangle$",
    #"F_phi_minus": r"Fidelity $|\Phi^-\rangle$",
    #"F_psi_plus": r"Fidelity $|\Psi^+\rangle$",
    #"F_psi_minus": r"Fidelity $|\Psi^-\rangle$"
}

my_e_ops = [
    #energy_solver, 
    concurrence_for_solver_general, 
    #xi_KU_solver
    ]

# %% [markdown]
# <font size="6">***Inefficient photodetection - 2 qubits, single dephasing***

# %% [markdown]
# ## Inefficient case: $|+ \! + \rangle$, $\quad \phi_1 = 0 \quad \phi_2 = 0$
#
# $$
# \left\{
# \begin{aligned}
# \hat{C}_1 &= e^{i \phi_{1}}\hat{C}_+ = \hat{C}_+\\
# \hat{C}_2 &= e^{i \phi_{2}}\hat{C}_- = \hat{C}_-
# \end{aligned}
# \right.
# $$

# %%
my_phis =[
    [0,0], 
    [0, np.pi/2], 
    [np.pi/2,0], 
    [np.pi/2, np.pi/2]
    ]

ntraj = 300

for phi_pair in my_phis:

    phi1, phi2 = phi_pair
    ineff_df = {}

    for eta,label in zip(my_eta, my_label_eta):

        my_photodetection = mcsolve(
            qutip.liouvillian(H_free, collapsing_operators(gamma, phi1, phi2, 1-eta)), 
            state, times,

            c_ops = collapsing_operators(gamma, phi1, phi2, eta),
            
            e_ops=my_e_ops,
            ntraj=ntraj,
            options=my_opts_dict
        )

        ineff_df[f"{label}"] = pd.DataFrame(np.transpose(my_photodetection.expect), columns=columns_label)

    
    #Setting the path to save the graphs
    phi1_dir = angle_to_path(phi1)
    phi2_dir = angle_to_path(phi2)
    my_directory = f".\\Graphs\\Jz_3_Ineff_Photodetection_SIM_other\\phi_1={phi1_dir}_phi_2={phi2_dir}"
    Path(my_directory).mkdir(parents=True, exist_ok=True)

    #My theoretical curves
    theo_curves = [np.sin(css_theta)**2 * np.exp(-(1-eta)*times)*(1-np.exp(-gamma*eta/2*times)) for eta in my_eta]

    #Plotting!
    for e_op in columns_label:
        #Un graph per ogni e_op, al variare di eta
        plt.figure(figsize=(12,8))
        graph_name = f"Ineff_{e_op}"

        for (label, df), eta, theory in zip(ineff_df.items(), my_eta, theo_curves):
            # x: tempo normalizzato a T1, y: media delle traiettorie
            x = times/T_1
            y = df[e_op]
            line_sim, = plt.plot(x, y, label=r"$\eta$ = " + str(eta))
            plt.plot(times/T_1, theory, '--', color=line_sim.get_color(), alpha=0.5, linewidth=2)

        #plt.ylim(-0.01, 1.02)
        plt.xlim(0,10)

        #plt.axhline(1, color="k", linewidth=1.6, linestyle="-", zorder=5)
        #plt.axhspan(1, 1.05, color="k", alpha=0.7, zorder=1, label="_nolegend_")

        plt.xlabel(r"$t/T_1$")
        plt.ylabel(label_graph_column[e_op])

        phi1_tex = angle_to_tex(phi1)
        phi2_tex = angle_to_tex(phi2)

        plt.title(r"Inefficient Photodetection: Average " + label_graph_column[e_op]+ r" over time"+ rf"$, \ \phi_1={phi1_tex}\ \ \phi_2={phi2_tex}$"
            + rf"  (n$_\mathrm{{traj}}$ = {ntraj})")
        plt.grid(True, linestyle=":", alpha=0.6)
        plt.legend(loc="upper left", bbox_to_anchor=(0, 0.95), fontsize=12)

        plt.savefig(Path(my_directory) / f"{graph_name}.pdf", bbox_inches="tight")
        plt.show()
# Out:
# 10.0%. Run time:   7.34s. Est. time left: 00:00:01:06
# 20.0%. Run time:  14.61s. Est. time left: 00:00:00:58
# 30.0%. Run time:  24.46s. Est. time left: 00:00:00:57
# 40.0%. Run time:  32.31s. Est. time left: 00:00:00:48
# 50.0%. Run time:  39.66s. Est. time left: 00:00:00:39
# 60.0%. Run time:  47.02s. Est. time left: 00:00:00:31
# 70.0%. Run time:  54.86s. Est. time left: 00:00:00:23
# 80.0%. Run time:  62.45s. Est. time left: 00:00:00:15
# 90.0%. Run time:  70.42s. Est. time left: 00:00:00:07
# 100.0%. Run time:  78.18s. Est. time left: 00:00:00:00
# Total run time:  78.45s
# 10.0%. Run time:   8.36s. Est. time left: 00:00:01:15
# 20.0%. Run time:  17.92s. Est. time left: 00:00:01:11
# 30.0%. Run time:  25.27s. Est. time left: 00:00:00:58
# 40.0%. Run time:  32.12s. Est. time left: 00:00:00:48
# 50.0%. Run time:  39.01s. Est. time left: 00:00:00:39
# 60.0%. Run time:  46.07s. Est. time left: 00:00:00:30
# 70.0%. Run time:  53.42s. Est. time left: 00:00:00:22
# 80.0%. Run time:  61.12s. Est. time left: 00:00:00:15
# 90.0%. Run time:  68.58s. Est. time left: 00:00:00:07
# 100.0%. Run time:  77.30s. Est. time left: 00:00:00:00
# Total run time:  77.74s
# 10.0%. Run time:  10.14s. Est. time left: 00:00:01:31
# 20.0%. Run time:  20.06s. Est. time left: 00:00:01:20
# 30.0%. Run time:  28.41s. Est. time left: 00:00:01:06
# 40.0%. Run time:  39.80s. Est. time left: 00:00:00:59
# 50.0%. Run time:  49.57s. Est. time left: 00:00:00:49
# 60.0%. Run time:  60.16s. Est. time left: 00:00:00:40
# 70.0%. Run time:  67.60s. Est. time left: 00:00:00:28
# 80.0%. Run time:  78.47s. Est. time left: 00:00:00:19
# 90.0%. Run time:  89.75s. Est. time left: 00:00:00:09
# 100.0%. Run time: 100.32s. Est. time left: 00:00:00:00
# Total run time: 100.60s
# 10.0%. Run time:   7.36s. Est. time left: 00:00:01:06
# 20.0%. Run time:  16.34s. Est. time left: 00:00:01:05
# 30.0%. Run time:  26.28s. Est. time left: 00:00:01:01
# 40.0%. Run time:  36.53s. Est. time left: 00:00:00:54
# 50.0%. Run time:  43.60s. Est. time left: 00:00:00:43
# 60.0%. Run time:  50.67s. Est. time left: 00:00:00:33
# 70.0%. Run time:  60.28s. Est. time left: 00:00:00:25
# 80.0%. Run time:  68.14s. Est. time left: 00:00:00:17
# 90.0%. Run time:  75.73s. Est. time left: 00:00:00:08
# 100.0%. Run time:  84.21s. Est. time left: 00:00:00:00
# Total run time:  84.48s
# 10.0%. Run time:  10.19s. Est. time left: 00:00:01:31
# 20.0%. Run time:  18.16s. Est. time left: 00:00:01:12
# 30.0%. Run time:  26.00s. Est. time left: 00:00:01:00
# 40.0%. Run time:  33.74s. Est. time left: 00:00:00:50
# 50.0%. Run time:  43.79s. Est. time left: 00:00:00:43
# 60.0%. Run time:  52.24s. Est. time left: 00:00:00:34
# 70.0%. Run time:  63.17s. Est. time left: 00:00:00:27
# 80.0%. Run time:  74.92s. Est. time left: 00:00:00:18
# 90.0%. Run time:  88.12s. Est. time left: 00:00:00:09
# 100.0%. Run time:  96.46s. Est. time left: 00:00:00:00
# Total run time:  96.75s
# 10.0%. Run time:  10.05s. Est. time left: 00:00:01:30
# 20.0%. Run time:  21.36s. Est. time left: 00:00:01:25
# 30.0%. Run time:  30.27s. Est. time left: 00:00:01:10
# 40.0%. Run time:  38.49s. Est. time left: 00:00:00:57
# 50.0%. Run time:  48.82s. Est. time left: 00:00:00:48
# 60.0%. Run time:  57.42s. Est. time left: 00:00:00:38
# 70.0%. Run time:  66.60s. Est. time left: 00:00:00:28
# 80.0%. Run time:  74.49s. Est. time left: 00:00:00:18
# 90.0%. Run time:  82.35s. Est. time left: 00:00:00:09
# 100.0%. Run time:  89.76s. Est. time left: 00:00:00:00
# Total run time:  90.01s
# 10.0%. Run time:   7.31s. Est. time left: 00:00:01:05
# 20.0%. Run time:  16.89s. Est. time left: 00:00:01:07
# 30.0%. Run time:  27.48s. Est. time left: 00:00:01:04
# 40.0%. Run time:  37.08s. Est. time left: 00:00:00:55
# 50.0%. Run time:  46.39s. Est. time left: 00:00:00:46
# 60.0%. Run time:  56.04s. Est. time left: 00:00:00:37
# 70.0%. Run time:  64.76s. Est. time left: 00:00:00:27
# 80.0%. Run time:  74.14s. Est. time left: 00:00:00:18
# 90.0%. Run time:  83.94s. Est. time left: 00:00:00:09
# 100.0%. Run time:  92.50s. Est. time left: 00:00:00:00
# Total run time:  92.77s
# 10.0%. Run time:   9.23s. Est. time left: 00:00:01:23
# 20.0%. Run time:  17.21s. Est. time left: 00:00:01:08
# 30.0%. Run time:  26.44s. Est. time left: 00:00:01:01
# 40.0%. Run time:  35.89s. Est. time left: 00:00:00:53
# 50.0%. Run time:  45.78s. Est. time left: 00:00:00:45
# 60.0%. Run time:  59.81s. Est. time left: 00:00:00:39
# 70.0%. Run time:  69.20s. Est. time left: 00:00:00:29
# 80.0%. Run time:  78.50s. Est. time left: 00:00:00:19
# 90.0%. Run time:  87.32s. Est. time left: 00:00:00:09
# 100.0%. Run time:  98.86s. Est. time left: 00:00:00:00
# Total run time:  99.18s
# 10.0%. Run time:  10.92s. Est. time left: 00:00:01:38
# 20.0%. Run time:  19.88s. Est. time left: 00:00:01:19
# 30.0%. Run time:  28.84s. Est. time left: 00:00:01:07
# 40.0%. Run time:  39.86s. Est. time left: 00:00:00:59
# 50.0%. Run time:  49.29s. Est. time left: 00:00:00:49
# 60.0%. Run time:  59.60s. Est. time left: 00:00:00:39
# 70.0%. Run time:  70.43s. Est. time left: 00:00:00:30
# 80.0%. Run time:  79.00s. Est. time left: 00:00:00:19
# 90.0%. Run time:  88.28s. Est. time left: 00:00:00:09
# 100.0%. Run time:  95.91s. Est. time left: 00:00:00:00
# Total run time:  96.18s
# 10.0%. Run time:   8.00s. Est. time left: 00:00:01:12
# 20.0%. Run time:  16.48s. Est. time left: 00:00:01:05
# 30.0%. Run time:  24.90s. Est. time left: 00:00:00:58
# 40.0%. Run time:  33.73s. Est. time left: 00:00:00:50
# 50.0%. Run time:  42.10s. Est. time left: 00:00:00:42
# 60.0%. Run time:  51.84s. Est. time left: 00:00:00:34
# 70.0%. Run time:  61.81s. Est. time left: 00:00:00:26
# 80.0%. Run time:  71.55s. Est. time left: 00:00:00:17
# 90.0%. Run time:  82.24s. Est. time left: 00:00:00:09
# 100.0%. Run time:  91.09s. Est. time left: 00:00:00:00
# Total run time:  91.37s
# 10.0%. Run time:   7.70s. Est. time left: 00:00:01:09
# 20.0%. Run time:  15.40s. Est. time left: 00:00:01:01
# 30.0%. Run time:  23.58s. Est. time left: 00:00:00:55
# 40.0%. Run time:  31.43s. Est. time left: 00:00:00:47
# 50.0%. Run time:  39.28s. Est. time left: 00:00:00:39
# 60.0%. Run time:  46.97s. Est. time left: 00:00:00:31
# 70.0%. Run time:  55.57s. Est. time left: 00:00:00:23
# 80.0%. Run time:  63.18s. Est. time left: 00:00:00:15
# 90.0%. Run time:  70.71s. Est. time left: 00:00:00:07
# 100.0%. Run time:  79.67s. Est. time left: 00:00:00:00
# Total run time:  80.00s
# 10.0%. Run time:   8.22s. Est. time left: 00:00:01:13
# 20.0%. Run time:  16.40s. Est. time left: 00:00:01:05
# 30.0%. Run time:  28.87s. Est. time left: 00:00:01:07
# 40.0%. Run time:  39.54s. Est. time left: 00:00:00:59
# 50.0%. Run time:  48.84s. Est. time left: 00:00:00:48
# 60.0%. Run time:  56.35s. Est. time left: 00:00:00:37
# 70.0%. Run time:  66.10s. Est. time left: 00:00:00:28
# 80.0%. Run time:  75.71s. Est. time left: 00:00:00:18
# 90.0%. Run time:  84.46s. Est. time left: 00:00:00:09
# 100.0%. Run time:  92.92s. Est. time left: 00:00:00:00
# Total run time:  93.13s
# 10.0%. Run time:  10.13s. Est. time left: 00:00:01:31
# 20.0%. Run time:  20.62s. Est. time left: 00:00:01:22
# 30.0%. Run time:  29.50s. Est. time left: 00:00:01:08
# 40.0%. Run time:  37.37s. Est. time left: 00:00:00:56
# 50.0%. Run time:  45.07s. Est. time left: 00:00:00:45
# 60.0%. Run time:  52.16s. Est. time left: 00:00:00:34
# 70.0%. Run time:  59.16s. Est. time left: 00:00:00:25
# 80.0%. Run time:  66.33s. Est. time left: 00:00:00:16
# 90.0%. Run time:  73.43s. Est. time left: 00:00:00:08
# 100.0%. Run time:  81.08s. Est. time left: 00:00:00:00
# Total run time:  81.35s
# 10.0%. Run time:   6.85s. Est. time left: 00:00:01:01
# 20.0%. Run time:  13.43s. Est. time left: 00:00:00:53
# 30.0%. Run time:  20.63s. Est. time left: 00:00:00:48
# 40.0%. Run time:  27.03s. Est. time left: 00:00:00:40
# 50.0%. Run time:  33.87s. Est. time left: 00:00:00:33
# 60.0%. Run time:  40.79s. Est. time left: 00:00:00:27
# 70.0%. Run time:  47.27s. Est. time left: 00:00:00:20
# 80.0%. Run time:  53.77s. Est. time left: 00:00:00:13
# 90.0%. Run time:  60.39s. Est. time left: 00:00:00:06
# 100.0%. Run time:  68.65s. Est. time left: 00:00:00:00
# Total run time:  68.92s
# 10.0%. Run time:   6.50s. Est. time left: 00:00:00:58
# 20.0%. Run time:  14.60s. Est. time left: 00:00:00:58
# 30.0%. Run time:  21.90s. Est. time left: 00:00:00:51
# 40.0%. Run time:  29.29s. Est. time left: 00:00:00:43
# 50.0%. Run time:  36.69s. Est. time left: 00:00:00:36
# 60.0%. Run time:  46.48s. Est. time left: 00:00:00:30
# 70.0%. Run time:  54.96s. Est. time left: 00:00:00:23
# 80.0%. Run time:  63.04s. Est. time left: 00:00:00:15
# 90.0%. Run time:  70.92s. Est. time left: 00:00:00:07
# 100.0%. Run time:  77.57s. Est. time left: 00:00:00:00
# Total run time:  77.80s
# 10.0%. Run time:   6.56s. Est. time left: 00:00:00:59
# 20.0%. Run time:  13.23s. Est. time left: 00:00:00:52
# 30.0%. Run time:  19.86s. Est. time left: 00:00:00:46
# 40.0%. Run time:  26.41s. Est. time left: 00:00:00:39
# 50.0%. Run time:  33.19s. Est. time left: 00:00:00:33
# 60.0%. Run time:  40.96s. Est. time left: 00:00:00:27
# 70.0%. Run time:  49.93s. Est. time left: 00:00:00:21
# 80.0%. Run time:  56.95s. Est. time left: 00:00:00:14
# 90.0%. Run time:  63.57s. Est. time left: 00:00:00:07
# 100.0%. Run time:  70.31s. Est. time left: 00:00:00:00
# Total run time:  70.55s
# 10.0%. Run time:   6.33s. Est. time left: 00:00:00:56
# 20.0%. Run time:  12.70s. Est. time left: 00:00:00:50
# 30.0%. Run time:  19.79s. Est. time left: 00:00:00:46
# 40.0%. Run time:  26.68s. Est. time left: 00:00:00:40
# 50.0%. Run time:  33.26s. Est. time left: 00:00:00:33
# 60.0%. Run time:  40.56s. Est. time left: 00:00:00:27
# 70.0%. Run time:  49.44s. Est. time left: 00:00:00:21
# 80.0%. Run time:  57.61s. Est. time left: 00:00:00:14
# 90.0%. Run time:  66.01s. Est. time left: 00:00:00:07
# 100.0%. Run time:  73.37s. Est. time left: 00:00:00:00
# Total run time:  73.68s
# 10.0%. Run time:  10.39s. Est. time left: 00:00:01:33
# 20.0%. Run time:  17.64s. Est. time left: 00:00:01:10
# 30.0%. Run time:  24.65s. Est. time left: 00:00:00:57
# 40.0%. Run time:  32.07s. Est. time left: 00:00:00:48
# 50.0%. Run time:  41.05s. Est. time left: 00:00:00:41
# 60.0%. Run time:  49.02s. Est. time left: 00:00:00:32
# 70.0%. Run time:  58.00s. Est. time left: 00:00:00:24
# 80.0%. Run time:  66.88s. Est. time left: 00:00:00:16
# 90.0%. Run time:  73.64s. Est. time left: 00:00:00:08
# 100.0%. Run time:  80.52s. Est. time left: 00:00:00:00
# Total run time:  80.84s
# 10.0%. Run time:   9.00s. Est. time left: 00:00:01:21
# 20.0%. Run time:  16.57s. Est. time left: 00:00:01:06
# 30.0%. Run time:  24.39s. Est. time left: 00:00:00:56
# 40.0%. Run time:  33.20s. Est. time left: 00:00:00:49
# 50.0%. Run time:  42.88s. Est. time left: 00:00:00:42
# 60.0%. Run time:  50.91s. Est. time left: 00:00:00:33
# 70.0%. Run time:  58.57s. Est. time left: 00:00:00:25
# 80.0%. Run time:  68.82s. Est. time left: 00:00:00:17
# 90.0%. Run time:  76.75s. Est. time left: 00:00:00:08
# 100.0%. Run time:  87.51s. Est. time left: 00:00:00:00
# Total run time:  87.75s
# 10.0%. Run time:   9.10s. Est. time left: 00:00:01:21
# 20.0%. Run time:  17.15s. Est. time left: 00:00:01:08
# 30.0%. Run time:  25.98s. Est. time left: 00:00:01:00
# 40.0%. Run time:  34.23s. Est. time left: 00:00:00:51
# 50.0%. Run time:  41.20s. Est. time left: 00:00:00:41
# 60.0%. Run time:  48.77s. Est. time left: 00:00:00:32
# 70.0%. Run time:  61.12s. Est. time left: 00:00:00:26
# 80.0%. Run time:  69.49s. Est. time left: 00:00:00:17
# 90.0%. Run time:  78.63s. Est. time left: 00:00:00:08
# 100.0%. Run time:  86.15s. Est. time left: 00:00:00:00
# Total run time:  86.39s
