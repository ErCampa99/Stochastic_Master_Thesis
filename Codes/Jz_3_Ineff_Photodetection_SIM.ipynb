# %%
import importlib
import quantum_function
importlib.reload(quantum_function)

from quantum_function import *
from IPython.display import display, Markdown

# %%
# --- SAFETY SWITCH: esce subito se non abiliti esplicitamente ---
RUN_THIS_CELL = True   # metti True solo quando vuoi davvero eseguire

if not RUN_THIS_CELL:
    display(Markdown("Cell locked. Set `RUN_THIS_CELL = True` to run"))
    raise SystemExit




plt.rcParams["text.usetex"] = True
plt.rcParams.update({
    "mathtext.fontset": "cm",      # font simile a LaTeX
    "font.family": "serif",
    "font.size": 14,
    "axes.unicode_minus": False
})

# %%
#PARAMETERS!

gamma = 1        # Atom decay rate
T_1 = 1 / gamma  # time constant for the decay

times = np.array(np.arange(0, 10*T_1, 0.01*T_1)) 

my_label_eta = ["1", "0.9", "0.7", "0.5", "0.3"] 

my_eta = [1, 0.9, 0.7, 0.5, 0.3] #etas for the homodyne detection

state = css_2(np.pi/4, phi=0)

my_opts_dict = {
    "keep_runs_results": False,
    #"map":"parallel",
    #"normalize_output" : False,
    #"store_final_state" : False,
    #"store_states": False,
    #"store_measurement": False,
    #"progress_bar": "Enhanced",
    "num_cpus": os.cpu_count()-1,
    }

columns_label = [
                #"Energy",
                 "Conc",
                 #"Xi2_KU",
                 #"F_phi_plus",
                 #"F_phi_minus",
                 #"F_psi_plus",
                 #"F_psi_minus"
            ]

label_graph_column = {
    #"Energy": r"Energy",
    "Conc": r"$\overline{\mathcal{C}}$",
    #"Xi2_KU": r"$\xi^2_{KU}$",
    #"F_phi_plus": r"Fidelity $|\Phi^+\rangle$",
    #"F_phi_minus": r"Fidelity $|\Phi^-\rangle$",
    #"F_psi_plus": r"Fidelity $|\Psi^+\rangle$",
    #"F_psi_minus": r"Fidelity $|\Psi^-\rangle$"
}

my_e_ops = [
    #energy_solver, 
    concurrence_for_solver_general, 
    #xi_KU_solver
    ]

# %% [markdown]
# <font size="6">***Inefficient photodetection - 2 qubits, single dephasing***

# %% [markdown]
# ## Inefficient case: $|+ \! + \rangle$, $\quad \phi_1 = 0 \quad \phi_2 = 0$
#
# $$
# \left\{
# \begin{aligned}
# \hat{C}_1 &= e^{i \phi_{1}}\hat{C}_+ = \hat{C}_+\\
# \hat{C}_2 &= e^{i \phi_{2}}\hat{C}_- = \hat{C}_-
# \end{aligned}
# \right.
# $$

# %%
my_phis =[
    [0,0], 
    [0, np.pi/2], 
    [np.pi/2,0], 
    [np.pi/2, np.pi/2]
    ]

ntraj = 100

for phi_pair in my_phis:

    phi1, phi2 = phi_pair
    ineff_df = {}

    for eta,label in zip(my_eta, my_label_eta):

        my_photodetection = mcsolve(
            qutip.liouvillian(H_free, collapsing_operators(gamma, phi1, phi2, 1-eta)), 
            state, times,

            c_ops = collapsing_operators(gamma, phi1, phi2, eta),
            
            e_ops=my_e_ops,
            ntraj=ntraj,
            options=my_opts_dict
        )

        ineff_df[f"{label}"] = pd.DataFrame(np.transpose(my_photodetection.expect), columns=columns_label)

    
    #Setting the path to save the graphs
    phi1_dir = angle_to_path(phi1)
    phi2_dir = angle_to_path(phi2)
    my_directory = f".\\Graphs\\Jz_3_Ineff_Photodetection_SIM_other\\phi_1={phi1_dir}_phi_2={phi2_dir}"
    Path(my_directory).mkdir(parents=True, exist_ok=True)

    #My theoretical curves
    theo_curves = [np.exp(-(1-eta)*times)*(1-np.exp(-gamma*eta/2*times)) for eta in my_eta]

    #Plotting!
    for e_op in columns_label:
        #Un graph per ogni e_op, al variare di eta
        plt.figure(figsize=(12,8))
        graph_name = f"Ineff_{e_op}"

        for (label, df), eta, theory in zip(ineff_df.items(), my_eta, theo_curves):
            # x: tempo normalizzato a T1, y: media delle traiettorie
            x = times/T_1
            y = df[e_op]
            line_sim, = plt.plot(x, y, label=r"$\eta$ = " + str(eta))
            plt.plot(times/T_1, theory, '--', color=line_sim.get_color(), alpha=0.5, linewidth=2)

        #plt.ylim(-0.01, 1.02)
        plt.xlim(0,10)

        #plt.axhline(1, color="k", linewidth=1.6, linestyle="-", zorder=5)
        #plt.axhspan(1, 1.05, color="k", alpha=0.7, zorder=1, label="_nolegend_")

        plt.xlabel(r"$t/T_1$")
        plt.ylabel(label_graph_column[e_op])

        phi1_tex = angle_to_tex(phi1)
        phi2_tex = angle_to_tex(phi2)

        plt.title(r"Inefficient Photodetection: Average " + label_graph_column[e_op]+ r" over time"+ rf"$, \ \phi_1={phi1_tex}\ \ \phi_2={phi2_tex}$"
            + rf"  (n$_\mathrm{{traj}}$ = {ntraj})")
        plt.grid(True, linestyle=":", alpha=0.6)
        plt.legend(loc="upper left", bbox_to_anchor=(0, 0.95), fontsize=12)

        plt.savefig(Path(my_directory) / f"{graph_name}.pdf", bbox_inches="tight")
        plt.show()
# Out:
# 10.0%. Run time:   4.04s. Est. time left: 00:00:00:36
# 20.0%. Run time:   7.98s. Est. time left: 00:00:00:31
# 30.0%. Run time:  11.84s. Est. time left: 00:00:00:27
# 40.0%. Run time:  15.39s. Est. time left: 00:00:00:23
# 50.0%. Run time:  19.57s. Est. time left: 00:00:00:19
# 60.0%. Run time:  23.96s. Est. time left: 00:00:00:15
# 70.0%. Run time:  27.42s. Est. time left: 00:00:00:11
# 80.0%. Run time:  31.02s. Est. time left: 00:00:00:07
# 90.0%. Run time:  34.35s. Est. time left: 00:00:00:03
# 100.0%. Run time:  37.72s. Est. time left: 00:00:00:00
# Total run time:  38.07s
# 10.0%. Run time:   3.08s. Est. time left: 00:00:00:27
# 20.0%. Run time:   7.40s. Est. time left: 00:00:00:29
# 30.0%. Run time:  14.76s. Est. time left: 00:00:00:34
# 40.0%. Run time:  24.45s. Est. time left: 00:00:00:36
# 50.0%. Run time:  30.15s. Est. time left: 00:00:00:30
# 60.0%. Run time:  35.34s. Est. time left: 00:00:00:23
# 70.0%. Run time:  40.65s. Est. time left: 00:00:00:17
# 80.0%. Run time:  44.66s. Est. time left: 00:00:00:11
# 90.0%. Run time:  48.86s. Est. time left: 00:00:00:05
# 100.0%. Run time:  52.82s. Est. time left: 00:00:00:00
# Total run time:  53.26s
# 10.0%. Run time:   3.73s. Est. time left: 00:00:00:33
# 20.0%. Run time:   7.40s. Est. time left: 00:00:00:29
# 30.0%. Run time:  10.83s. Est. time left: 00:00:00:25
# 40.0%. Run time:  14.23s. Est. time left: 00:00:00:21
# 50.0%. Run time:  18.02s. Est. time left: 00:00:00:18
# 60.0%. Run time:  21.70s. Est. time left: 00:00:00:14
# 70.0%. Run time:  25.22s. Est. time left: 00:00:00:10
# 80.0%. Run time:  28.64s. Est. time left: 00:00:00:07
# 90.0%. Run time:  32.36s. Est. time left: 00:00:00:03
# 100.0%. Run time:  35.92s. Est. time left: 00:00:00:00
# Total run time:  36.29s
# 10.0%. Run time:   3.19s. Est. time left: 00:00:00:28
# 20.0%. Run time:   6.60s. Est. time left: 00:00:00:26
# 30.0%. Run time:  10.21s. Est. time left: 00:00:00:23
# 40.0%. Run time:  13.98s. Est. time left: 00:00:00:20
# 50.0%. Run time:  17.75s. Est. time left: 00:00:00:17
# 60.0%. Run time:  21.94s. Est. time left: 00:00:00:14
# 70.0%. Run time:  26.15s. Est. time left: 00:00:00:11
# 80.0%. Run time:  30.08s. Est. time left: 00:00:00:07
# 90.0%. Run time:  33.65s. Est. time left: 00:00:00:03
# 100.0%. Run time:  37.21s. Est. time left: 00:00:00:00
# Total run time:  37.76s
# 10.0%. Run time:   3.83s. Est. time left: 00:00:00:34
# 20.0%. Run time:   7.67s. Est. time left: 00:00:00:30
# 30.0%. Run time:  11.72s. Est. time left: 00:00:00:27
# 40.0%. Run time:  16.06s. Est. time left: 00:00:00:24
# 50.0%. Run time:  19.99s. Est. time left: 00:00:00:19
# 60.0%. Run time:  24.06s. Est. time left: 00:00:00:16
# 70.0%. Run time:  28.08s. Est. time left: 00:00:00:12
# 80.0%. Run time:  31.61s. Est. time left: 00:00:00:07
# 90.0%. Run time:  35.51s. Est. time left: 00:00:00:03
# 100.0%. Run time:  39.56s. Est. time left: 00:00:00:00
# Total run time:  40.23s
# 10.0%. Run time:   4.09s. Est. time left: 00:00:00:36
# 20.0%. Run time:   7.24s. Est. time left: 00:00:00:28
# 30.0%. Run time:  12.19s. Est. time left: 00:00:00:28
# 40.0%. Run time:  15.64s. Est. time left: 00:00:00:23
# 50.0%. Run time:  18.94s. Est. time left: 00:00:00:18
# 60.0%. Run time:  22.38s. Est. time left: 00:00:00:14
# 70.0%. Run time:  26.25s. Est. time left: 00:00:00:11
# 80.0%. Run time:  30.74s. Est. time left: 00:00:00:07
# 90.0%. Run time:  34.60s. Est. time left: 00:00:00:03
# 100.0%. Run time:  39.03s. Est. time left: 00:00:00:00
# Total run time:  39.40s
# 10.0%. Run time:   3.19s. Est. time left: 00:00:00:28
# 20.0%. Run time:   6.92s. Est. time left: 00:00:00:27
# 30.0%. Run time:  10.59s. Est. time left: 00:00:00:24
# 40.0%. Run time:  14.28s. Est. time left: 00:00:00:21
# 50.0%. Run time:  17.88s. Est. time left: 00:00:00:17
# 60.0%. Run time:  21.29s. Est. time left: 00:00:00:14
# 70.0%. Run time:  24.89s. Est. time left: 00:00:00:10
# 80.0%. Run time:  28.72s. Est. time left: 00:00:00:07
# 90.0%. Run time:  32.08s. Est. time left: 00:00:00:03
# 100.0%. Run time:  36.07s. Est. time left: 00:00:00:00
# Total run time:  36.55s
# 10.0%. Run time:   4.08s. Est. time left: 00:00:00:36
# 20.0%. Run time:   7.86s. Est. time left: 00:00:00:31
# 30.0%. Run time:  11.57s. Est. time left: 00:00:00:26
# 40.0%. Run time:  15.24s. Est. time left: 00:00:00:22
# 50.0%. Run time:  19.28s. Est. time left: 00:00:00:19
# 60.0%. Run time:  23.58s. Est. time left: 00:00:00:15
# 70.0%. Run time:  27.59s. Est. time left: 00:00:00:11
# 80.0%. Run time:  31.78s. Est. time left: 00:00:00:07
# 90.0%. Run time:  35.54s. Est. time left: 00:00:00:03
# 100.0%. Run time:  39.82s. Est. time left: 00:00:00:00
# Total run time:  40.14s
# 10.0%. Run time:   3.79s. Est. time left: 00:00:00:34
# 20.0%. Run time:   7.92s. Est. time left: 00:00:00:31
# 30.0%. Run time:  11.65s. Est. time left: 00:00:00:27
# 40.0%. Run time:  15.91s. Est. time left: 00:00:00:23
# 50.0%. Run time:  19.97s. Est. time left: 00:00:00:19
# 60.0%. Run time:  25.49s. Est. time left: 00:00:00:16
# 70.0%. Run time:  31.81s. Est. time left: 00:00:00:13
# 80.0%. Run time:  36.27s. Est. time left: 00:00:00:09
# 90.0%. Run time:  40.82s. Est. time left: 00:00:00:04
# 100.0%. Run time:  44.88s. Est. time left: 00:00:00:00
# Total run time:  45.23s
# 10.0%. Run time:   3.45s. Est. time left: 00:00:00:31
# 20.0%. Run time:   6.93s. Est. time left: 00:00:00:27
# 30.0%. Run time:  10.99s. Est. time left: 00:00:00:25
# 40.0%. Run time:  14.65s. Est. time left: 00:00:00:21
# 50.0%. Run time:  18.23s. Est. time left: 00:00:00:18
# 60.0%. Run time:  21.97s. Est. time left: 00:00:00:14
# 70.0%. Run time:  28.01s. Est. time left: 00:00:00:12
# 80.0%. Run time:  34.30s. Est. time left: 00:00:00:08
# 90.0%. Run time:  39.99s. Est. time left: 00:00:00:04
# 100.0%. Run time:  44.97s. Est. time left: 00:00:00:00
# Total run time:  45.58s
# 10.0%. Run time:   4.08s. Est. time left: 00:00:00:36
# 20.0%. Run time:  10.07s. Est. time left: 00:00:00:40
# 30.0%. Run time:  15.55s. Est. time left: 00:00:00:36
# 40.0%. Run time:  20.67s. Est. time left: 00:00:00:30
# 50.0%. Run time:  24.52s. Est. time left: 00:00:00:24
# 60.0%. Run time:  28.44s. Est. time left: 00:00:00:18
# 70.0%. Run time:  33.14s. Est. time left: 00:00:00:14
# 80.0%. Run time:  38.09s. Est. time left: 00:00:00:09
# 90.0%. Run time:  45.48s. Est. time left: 00:00:00:05
# 100.0%. Run time:  50.15s. Est. time left: 00:00:00:00
# Total run time:  50.56s
# 10.0%. Run time:   4.96s. Est. time left: 00:00:00:44
# 20.0%. Run time:  11.85s. Est. time left: 00:00:00:47
# 30.0%. Run time:  17.58s. Est. time left: 00:00:00:41
# 40.0%. Run time:  23.63s. Est. time left: 00:00:00:35
# 50.0%. Run time:  27.70s. Est. time left: 00:00:00:27
# 60.0%. Run time:  31.84s. Est. time left: 00:00:00:21
# 70.0%. Run time:  35.88s. Est. time left: 00:00:00:15
# 80.0%. Run time:  39.19s. Est. time left: 00:00:00:09
# 90.0%. Run time:  42.92s. Est. time left: 00:00:00:04
# 100.0%. Run time:  47.15s. Est. time left: 00:00:00:00
# Total run time:  47.63s
# 10.0%. Run time:   4.73s. Est. time left: 00:00:00:42
# 20.0%. Run time:   9.46s. Est. time left: 00:00:00:37
# 30.0%. Run time:  12.75s. Est. time left: 00:00:00:29
# 40.0%. Run time:  16.47s. Est. time left: 00:00:00:24
# 50.0%. Run time:  20.17s. Est. time left: 00:00:00:20
# 60.0%. Run time:  23.74s. Est. time left: 00:00:00:15
# 70.0%. Run time:  27.30s. Est. time left: 00:00:00:11
# 80.0%. Run time:  30.94s. Est. time left: 00:00:00:07
# 90.0%. Run time:  34.71s. Est. time left: 00:00:00:03
# 100.0%. Run time:  38.37s. Est. time left: 00:00:00:00
# Total run time:  38.70s
# 10.0%. Run time:   3.23s. Est. time left: 00:00:00:29
# 20.0%. Run time:   6.88s. Est. time left: 00:00:00:27
# 30.0%. Run time:  10.75s. Est. time left: 00:00:00:25
# 40.0%. Run time:  14.39s. Est. time left: 00:00:00:21
# 50.0%. Run time:  18.29s. Est. time left: 00:00:00:18
# 60.0%. Run time:  22.25s. Est. time left: 00:00:00:14
# 70.0%. Run time:  25.68s. Est. time left: 00:00:00:11
# 80.0%. Run time:  29.36s. Est. time left: 00:00:00:07
# 90.0%. Run time:  33.05s. Est. time left: 00:00:00:03
# 100.0%. Run time:  36.47s. Est. time left: 00:00:00:00
# Total run time:  36.82s
# 10.0%. Run time:   2.92s. Est. time left: 00:00:00:26
# 20.0%. Run time:   6.27s. Est. time left: 00:00:00:25
# 30.0%. Run time:  10.46s. Est. time left: 00:00:00:24
# 40.0%. Run time:  13.92s. Est. time left: 00:00:00:20
# 50.0%. Run time:  17.22s. Est. time left: 00:00:00:17
# 60.0%. Run time:  20.86s. Est. time left: 00:00:00:13
# 70.0%. Run time:  25.09s. Est. time left: 00:00:00:10
# 80.0%. Run time:  29.37s. Est. time left: 00:00:00:07
# 90.0%. Run time:  32.76s. Est. time left: 00:00:00:03
# 100.0%. Run time:  36.52s. Est. time left: 00:00:00:00
# Total run time:  36.88s
# 10.0%. Run time:   3.05s. Est. time left: 00:00:00:27
# 20.0%. Run time:   6.50s. Est. time left: 00:00:00:26
# 30.0%. Run time:   9.90s. Est. time left: 00:00:00:23
# 40.0%. Run time:  13.47s. Est. time left: 00:00:00:20
# 50.0%. Run time:  17.42s. Est. time left: 00:00:00:17
# 60.0%. Run time:  20.80s. Est. time left: 00:00:00:13
# 70.0%. Run time:  24.13s. Est. time left: 00:00:00:10
# 80.0%. Run time:  27.77s. Est. time left: 00:00:00:06
# 90.0%. Run time:  31.48s. Est. time left: 00:00:00:03
# 100.0%. Run time:  35.10s. Est. time left: 00:00:00:00
# Total run time:  35.46s
# 10.0%. Run time:   3.37s. Est. time left: 00:00:00:30
# 20.0%. Run time:   6.83s. Est. time left: 00:00:00:27
# 30.0%. Run time:  11.41s. Est. time left: 00:00:00:26
# 40.0%. Run time:  15.02s. Est. time left: 00:00:00:22
# 50.0%. Run time:  18.57s. Est. time left: 00:00:00:18
# 60.0%. Run time:  21.87s. Est. time left: 00:00:00:14
# 70.0%. Run time:  25.54s. Est. time left: 00:00:00:10
# 80.0%. Run time:  28.99s. Est. time left: 00:00:00:07
# 90.0%. Run time:  32.74s. Est. time left: 00:00:00:03
# 100.0%. Run time:  36.36s. Est. time left: 00:00:00:00
# Total run time:  36.71s
# 10.0%. Run time:   2.88s. Est. time left: 00:00:00:25
# 20.0%. Run time:   6.48s. Est. time left: 00:00:00:25
# 30.0%. Run time:  10.04s. Est. time left: 00:00:00:23
# 40.0%. Run time:  13.60s. Est. time left: 00:00:00:20
# 50.0%. Run time:  16.98s. Est. time left: 00:00:00:16
# 60.0%. Run time:  20.31s. Est. time left: 00:00:00:13
# 70.0%. Run time:  23.89s. Est. time left: 00:00:00:10
# 80.0%. Run time:  28.03s. Est. time left: 00:00:00:07
# 90.0%. Run time:  31.83s. Est. time left: 00:00:00:03
# 100.0%. Run time:  35.10s. Est. time left: 00:00:00:00
# Total run time:  35.49s
# 10.0%. Run time:   3.09s. Est. time left: 00:00:00:27
# 20.0%. Run time:   7.83s. Est. time left: 00:00:00:31
# 30.0%. Run time:  12.19s. Est. time left: 00:00:00:28
# 40.0%. Run time:  16.26s. Est. time left: 00:00:00:24
# 50.0%. Run time:  20.49s. Est. time left: 00:00:00:20
# 60.0%. Run time:  26.57s. Est. time left: 00:00:00:17
# 70.0%. Run time:  32.81s. Est. time left: 00:00:00:14
# 80.0%. Run time:  40.62s. Est. time left: 00:00:00:10
# 90.0%. Run time:  44.74s. Est. time left: 00:00:00:04
# 100.0%. Run time:  49.02s. Est. time left: 00:00:00:00
# Total run time:  49.51s
# 10.0%. Run time:   4.25s. Est. time left: 00:00:00:38
# 20.0%. Run time:   9.39s. Est. time left: 00:00:00:37
# 30.0%. Run time:  14.36s. Est. time left: 00:00:00:33
# 40.0%. Run time:  18.52s. Est. time left: 00:00:00:27
# 50.0%. Run time:  22.62s. Est. time left: 00:00:00:22
# 60.0%. Run time:  26.63s. Est. time left: 00:00:00:17
# 70.0%. Run time:  32.36s. Est. time left: 00:00:00:13
# 80.0%. Run time:  36.76s. Est. time left: 00:00:00:09
# 90.0%. Run time:  40.57s. Est. time left: 00:00:00:04
# 100.0%. Run time:  44.60s. Est. time left: 00:00:00:00
# Total run time:  45.01s
