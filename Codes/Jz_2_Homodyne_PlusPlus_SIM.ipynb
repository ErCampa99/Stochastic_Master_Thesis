# %%
import importlib
import quantum_function
importlib.reload(quantum_function)

from quantum_function import *
from IPython.display import display, Markdown

# %%
# --- SAFETY SWITCH: esce subito se non abiliti esplicitamente ---
RUN_THIS_CELL = True   # metti True solo quando vuoi davvero eseguire

if not RUN_THIS_CELL:
    display(Markdown("Cell locked. Set `RUN_THIS_CELL = True` to run"))
    raise SystemExit



plt.rcParams["text.usetex"] = True
plt.rcParams.update({
    "mathtext.fontset": "cm",      # font simile a LaTeX
    "font.family": "serif",
    "font.size": 14,
    "axes.unicode_minus": False
})

# %%
#PARAMETERS!

gamma = 1        # Atom decay rate
T_1 = 1 / gamma  # time constant for the decay

times = np.array(np.arange(0, 10*T_1, 0.01*T_1)) 

my_label_eta = ["1", "0.9", "0.7", "0.5", "0.3"] 

my_eta = [1, 0.9, 0.7, 0.5, 0.3] #etas for the homodyne detection

theta_css = np.pi/2
state = css_2(theta_css, phi=0)

my_phis =[
    [0,0], 
    [0, np.pi/2], 
    [np.pi/2,0], 
    [np.pi/2, np.pi/2]
    ]

ntraj = 10

my_opts_dict = {
    "keep_runs_results": False,
    #"map":"parallel",
    #"normalize_output" : False,
    #"store_final_state" : False,
    #"store_states": False,
    #"store_measurement": False,
    #"progress_bar": "Enhanced",
    "num_cpus": os.cpu_count()-1,
    }

columns_label = [
                #"Energy",
                 "Conc",
                 #"Xi2_KU",
                 #"F_phi_plus",
                 #"F_phi_minus",
                 #"F_psi_plus",
                 #"F_psi_minus"
            ]

label_graph_column = {
    #"Energy": r"Energy",
    "Conc": r"$\overline{\mathcal{C}}$",
    #"Xi2_KU": r"$\xi^2_{KU}$",
    #"F_phi_plus": r"Fidelity $|\Phi^+\rangle$",
    #"F_phi_minus": r"Fidelity $|\Phi^-\rangle$",
    #"F_psi_plus": r"Fidelity $|\Psi^+\rangle$",
    #"F_psi_minus": r"Fidelity $|\Psi^-\rangle$"
}

my_e_ops = [
    #energy_solver, 
    concurrence_for_solver_general, 
    #xi_KU_solver
    ]

# %% [markdown]
# <font size="6">***Inefficient homodyne detection - 2 qubits $|+ \! +\rangle$, single dephasing***

# %% [markdown]
# ## Inefficient case: $|+ \! + \rangle$, $\quad \phi_1, \quad \phi_2$
#
# $$
# \left\{
# \begin{aligned}
# \hat{C}_1 &= e^{i \phi_{1}}\hat{C}_+ \\
# \hat{C}_2 &= e^{i \phi_{2}}\hat{C}_-
# \end{aligned}
# \right.
# $$

# %%
for phi_pair in my_phis:

    phi1, phi2 = phi_pair
    ineff_df = {}

    for eta,label in zip(my_eta, my_label_eta):

        my_photodetection = smesolve(
            H_free, state, times,

            c_ops = collapsing_operators(gamma, phi1, phi2, 1-eta),
            sc_ops = collapsing_operators(gamma, phi1, phi2, eta),

            heterodyne = False,
            
            e_ops=my_e_ops,
            ntraj=ntraj,
            options=my_opts_dict
        )

        ineff_df[f"{label}"] = pd.DataFrame(np.transpose(my_photodetection.expect), columns=columns_label)



    #Setting the path to save the graphs
    phi1_dir = angle_to_path(phi1)
    phi2_dir = angle_to_path(phi2)
    my_directory = f".\\Graphs\\Jz_2_Homodyne_SIM_other\\phi_1={phi1_dir}_phi_2={phi2_dir}"
    Path(my_directory).mkdir(parents=True, exist_ok=True)

    #My theoretical curves
    theo_curves = [np.sin(theta_css)**2 * np.exp(-(1-eta)*times)*(1-np.exp(-gamma*eta/2*times)) for eta in my_eta]

    #Plotting!
    for e_op in columns_label:
        #Un graph per ogni e_op, al variare di eta
        plt.figure(figsize=(12,8))
        graph_name = f"Ineff_{e_op}"

        for (label, df), eta, theory in zip(ineff_df.items(), my_eta, theo_curves):
            # x: tempo normalizzato a T1, y: media delle traiettorie
            x = times/T_1
            y = df[e_op]
            line_sim, = plt.plot(x, y, label=r"$\eta$ = " + str(eta))
            plt.plot(times/T_1, theory, '--', color=line_sim.get_color(), alpha=0.5, linewidth=2)

        #plt.ylim(-0.01, 1.02)
        plt.xlim(0,10)

        #plt.axhline(1, color="k", linewidth=1.6, linestyle="-", zorder=5)
        #plt.axhspan(1, 1.05, color="k", alpha=0.7, zorder=1, label="_nolegend_")

        plt.xlabel(r"$t/T_1$")
        plt.ylabel(label_graph_column[e_op])

        phi1_tex = angle_to_tex(phi1)
        phi2_tex = angle_to_tex(phi2)

        plt.title(r"Homodyne: Average " + label_graph_column[e_op]+ r" over time"+ rf"$, \ \phi_1={phi1_tex}\ \ \phi_2={phi2_tex}$"
            + rf"  (n$_\mathrm{{traj}}$ = {ntraj})")
        plt.grid(True, linestyle=":", alpha=0.6)
        plt.legend(loc="upper left", bbox_to_anchor=(0, 0.95), fontsize=12)

        plt.savefig(Path(my_directory) / f"{graph_name}.pdf", bbox_inches="tight")
        plt.show()
# Out:
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.82s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.61s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.56s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.36s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.24s. Est. time left: 00:00:00:02
# 70.0%. Run time:   5.16s. Est. time left: 00:00:00:02
# 80.0%. Run time:   6.01s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.79s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.54s. Est. time left: 00:00:00:00
# Total run time:   8.28s
# 10.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.49s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.24s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.02s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.79s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.53s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.30s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.14s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.24s. Est. time left: 00:00:00:00
# Total run time:   8.01s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.79s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.66s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.90s. Est. time left: 00:00:00:04
# 50.0%. Run time:   3.96s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.93s. Est. time left: 00:00:00:03
# 70.0%. Run time:   5.91s. Est. time left: 00:00:00:02
# 80.0%. Run time:   6.80s. Est. time left: 00:00:00:01
# 90.0%. Run time:   7.78s. Est. time left: 00:00:00:00
# 100.0%. Run time:   8.78s. Est. time left: 00:00:00:00
# Total run time:   9.76s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   1.04s. Est. time left: 00:00:00:04
# 30.0%. Run time:   2.11s. Est. time left: 00:00:00:04
# 40.0%. Run time:   3.07s. Est. time left: 00:00:00:04
# 50.0%. Run time:   4.00s. Est. time left: 00:00:00:04
# 60.0%. Run time:   4.93s. Est. time left: 00:00:00:03
# 70.0%. Run time:   5.86s. Est. time left: 00:00:00:02
# 80.0%. Run time:   6.84s. Est. time left: 00:00:00:01
# 90.0%. Run time:   7.75s. Est. time left: 00:00:00:00
# 100.0%. Run time:   8.58s. Est. time left: 00:00:00:00
# Total run time:   9.37s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.76s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.51s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.29s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.04s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.81s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.55s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.32s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.08s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.83s. Est. time left: 00:00:00:00
# Total run time:   7.58s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.88s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.61s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.55s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.33s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.11s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.85s. Est. time left: 00:00:00:02
# 80.0%. Run time:   5.61s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.40s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.17s. Est. time left: 00:00:00:00
# Total run time:   7.91s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.77s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.51s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.26s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.02s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.78s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.65s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.46s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.25s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.21s. Est. time left: 00:00:00:00
# Total run time:   7.92s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.77s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.55s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.36s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.10s. Est. time left: 00:00:00:03
# 60.0%. Run time:   3.80s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.51s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.17s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.88s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.70s. Est. time left: 00:00:00:00
# Total run time:   7.45s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.76s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.54s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.40s. Est. time left: 00:00:00:03
# 50.0%. Run time:   3.26s. Est. time left: 00:00:00:03
# 60.0%. Run time:   4.21s. Est. time left: 00:00:00:02
# 70.0%. Run time:   5.03s. Est. time left: 00:00:00:02
# 80.0%. Run time:   5.74s. Est. time left: 00:00:00:01
# 90.0%. Run time:   6.48s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.22s. Est. time left: 00:00:00:00
# Total run time:   7.93s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.71s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.42s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.16s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.87s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.58s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.29s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.01s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.72s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.43s. Est. time left: 00:00:00:00
# Total run time:   7.16s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.82s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.52s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.24s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.96s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.66s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.36s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.07s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.78s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.47s. Est. time left: 00:00:00:00
# Total run time:   7.20s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.71s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.46s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.17s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.87s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.56s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.27s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.96s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.66s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.37s. Est. time left: 00:00:00:00
# Total run time:   7.10s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.76s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.46s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.17s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.89s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.60s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.31s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.03s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.74s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.47s. Est. time left: 00:00:00:00
# Total run time:   7.18s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.70s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.39s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.08s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.79s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.48s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.19s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.89s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.59s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.29s. Est. time left: 00:00:00:00
# Total run time:   6.99s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.69s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.38s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.09s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.78s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.49s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.18s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.89s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.60s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.30s. Est. time left: 00:00:00:00
# Total run time:   7.00s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.82s. Est. time left: 00:00:00:03
# 30.0%. Run time:   1.53s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.26s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.97s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.67s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.38s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.09s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.79s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.58s. Est. time left: 00:00:00:00
# Total run time:   7.30s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.71s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.41s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.12s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.84s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.56s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.25s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.95s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.65s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.36s. Est. time left: 00:00:00:00
# Total run time:   7.06s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.71s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.42s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.14s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.85s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.58s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.31s. Est. time left: 00:00:00:01
# 80.0%. Run time:   5.04s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.74s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.44s. Est. time left: 00:00:00:00
# Total run time:   7.15s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.69s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.41s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.11s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.81s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.52s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.24s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.95s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.64s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.36s. Est. time left: 00:00:00:00
# Total run time:   7.05s
# 10.0%. Run time:   0.00s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.69s. Est. time left: 00:00:00:02
# 30.0%. Run time:   1.40s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.10s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.80s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.48s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.17s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.87s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.59s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.29s. Est. time left: 00:00:00:00
# Total run time:   6.98s
