# %%
import importlib
import quantum_function
importlib.reload(quantum_function)

from quantum_function import *
from IPython.display import display, Markdown

# %%
# --- SAFETY SWITCH: esce subito se non abiliti esplicitamente ---
RUN_THIS_CELL = True   # metti True solo quando vuoi davvero eseguire

if not RUN_THIS_CELL:
    display(Markdown("Cell locked. Set `RUN_THIS_CELL = True` to run"))
    raise SystemExit



plt.rcParams["text.usetex"] = True
plt.rcParams.update({
    "mathtext.fontset": "cm",      # font simile a LaTeX
    "font.family": "serif",
    "font.size": 14,
    "axes.unicode_minus": False
})

# %%
#PARAMETERS!

gamma = 1        # Atom decay rate
T_1 = 1 / gamma  # time constant for the decay

times = np.array(np.arange(0, 10*T_1, 0.01*T_1)) 

my_label_eta = ["1", "0.9", "0.7", "0.5", "0.3"] 

my_eta = [1, 0.9, 0.7, 0.5, 0.3] #etas for the homodyne detection

state = css_2(np.pi/4, phi=0)

my_opts_dict = {
    "keep_runs_results": False,
    #"map":"parallel",
    #"normalize_output" : False,
    #"store_final_state" : False,
    #"store_states": False,
    #"store_measurement": False,
    #"progress_bar": "Enhanced",
    "num_cpus": os.cpu_count()-1,
    }

columns_label = [
                #"Energy",
                 "Conc",
                 #"Xi2_KU",
                 #"F_phi_plus",
                 #"F_phi_minus",
                 #"F_psi_plus",
                 #"F_psi_minus"
            ]

label_graph_column = {
    #"Energy": r"Energy",
    "Conc": r"$\overline{\mathcal{C}}$",
    #"Xi2_KU": r"$\xi^2_{KU}$",
    #"F_phi_plus": r"Fidelity $|\Phi^+\rangle$",
    #"F_phi_minus": r"Fidelity $|\Phi^-\rangle$",
    #"F_psi_plus": r"Fidelity $|\Psi^+\rangle$",
    #"F_psi_minus": r"Fidelity $|\Psi^-\rangle$"
}

my_e_ops = [
    #energy_solver, 
    concurrence_for_solver_general, 
    #xi_KU_solver
    ]

# %% [markdown]
# <font size="6">***Inefficient photodetection - 2 qubits, single dephasing***

# %% [markdown]
# ## Inefficient case: $|+ \! + \rangle$, $\quad \phi_1 = 0 \quad \phi_2 = 0$
#
# $$
# \left\{
# \begin{aligned}
# \hat{C}_1 &= e^{i \phi_{1}}\hat{C}_+ = \hat{C}_+\\
# \hat{C}_2 &= e^{i \phi_{2}}\hat{C}_- = \hat{C}_-
# \end{aligned}
# \right.
# $$

# %%
my_phis =[
    [0,0], 
    [0, np.pi/2], 
    [np.pi/2,0], 
    [np.pi/2, np.pi/2]
    ]

ntraj = 100

for phi_pair in my_phis:

    phi1, phi2 = phi_pair
    ineff_df = {}

    for eta,label in zip(my_eta, my_label_eta):

        my_photodetection = smesolve(
            H_free, state, times,

            c_ops = collapsing_operators(gamma, phi1, phi2, 1-eta),
            sc_ops = collapsing_operators(gamma, phi1, phi2, eta),

            heterodyne = True,
            
            e_ops=my_e_ops,
            ntraj=ntraj,
            options=my_opts_dict
        )

        ineff_df[f"{label}"] = pd.DataFrame(np.transpose(my_photodetection.expect), columns=columns_label)



    #Setting the path to save the graphs
    phi1_dir = angle_to_path(phi1)
    phi2_dir = angle_to_path(phi2)
    my_directory = f".\\Graphs\\Jz_2_Heterodyne_SIM_other\\phi_1={phi1_dir}_phi_2={phi2_dir}"
    Path(my_directory).mkdir(parents=True, exist_ok=True)

    #My theoretical curves
    theo_curves = [np.exp(-(1-eta)*times)*(1-np.exp(-gamma*eta/2*times)) for eta in my_eta]

    #Plotting!
    for e_op in columns_label:
        #Un graph per ogni e_op, al variare di eta
        plt.figure(figsize=(12,8))
        graph_name = f"Ineff_{e_op}"

        for (label, df), eta, theory in zip(ineff_df.items(), my_eta, theo_curves):
            # x: tempo normalizzato a T1, y: media delle traiettorie
            x = times/T_1
            y = df[e_op]
            line_sim, = plt.plot(x, y, label=r"$\eta$ = " + str(eta))
            plt.plot(times/T_1, theory, '--', color=line_sim.get_color(), alpha=0.5, linewidth=2)

        #plt.ylim(-0.01, 1.02)
        plt.xlim(0,10)

        #plt.axhline(1, color="k", linewidth=1.6, linestyle="-", zorder=5)
        #plt.axhspan(1, 1.05, color="k", alpha=0.7, zorder=1, label="_nolegend_")

        plt.xlabel(r"$t/T_1$")
        plt.ylabel(label_graph_column[e_op])

        phi1_tex = angle_to_tex(phi1)
        phi2_tex = angle_to_tex(phi2)

        plt.title(r"Heterodyne: Average " + label_graph_column[e_op]+ r" over time"+ rf"$, \ \phi_1={phi1_tex}\ \ \phi_2={phi2_tex}$"
            + rf"  (n$_\mathrm{{traj}}$ = {ntraj})")
        plt.grid(True, linestyle=":", alpha=0.6)
        plt.legend(loc="upper left", bbox_to_anchor=(0, 0.95), fontsize=12)

        plt.savefig(Path(my_directory) / f"{graph_name}.pdf", bbox_inches="tight")
        plt.show()
# Out:
# 10.0%. Run time:   4.57s. Est. time left: 00:00:00:41
# 20.0%. Run time:   9.62s. Est. time left: 00:00:00:38
# 30.0%. Run time:  13.71s. Est. time left: 00:00:00:31
# 40.0%. Run time:  18.10s. Est. time left: 00:00:00:27
# 50.0%. Run time:  23.20s. Est. time left: 00:00:00:23
# 60.0%. Run time:  28.26s. Est. time left: 00:00:00:18
# 70.0%. Run time:  32.45s. Est. time left: 00:00:00:13
# 80.0%. Run time:  37.00s. Est. time left: 00:00:00:09
# 90.0%. Run time:  42.56s. Est. time left: 00:00:00:04
# 100.0%. Run time:  47.33s. Est. time left: 00:00:00:00
# Total run time:  47.59s
# 10.0%. Run time:   4.49s. Est. time left: 00:00:00:40
# 20.0%. Run time:   8.91s. Est. time left: 00:00:00:35
# 30.0%. Run time:  13.92s. Est. time left: 00:00:00:32
# 40.0%. Run time:  18.55s. Est. time left: 00:00:00:27
# 50.0%. Run time:  24.30s. Est. time left: 00:00:00:24
# 60.0%. Run time:  28.91s. Est. time left: 00:00:00:19
# 70.0%. Run time:  33.30s. Est. time left: 00:00:00:14
# 80.0%. Run time:  37.60s. Est. time left: 00:00:00:09
# 90.0%. Run time:  41.97s. Est. time left: 00:00:00:04
# 100.0%. Run time:  46.69s. Est. time left: 00:00:00:00
# Total run time:  46.96s
# 10.0%. Run time:   4.64s. Est. time left: 00:00:00:41
# 20.0%. Run time:   9.42s. Est. time left: 00:00:00:37
# 30.0%. Run time:  14.31s. Est. time left: 00:00:00:33
# 40.0%. Run time:  19.12s. Est. time left: 00:00:00:28
# 50.0%. Run time:  23.42s. Est. time left: 00:00:00:23
# 60.0%. Run time:  27.64s. Est. time left: 00:00:00:18
# 70.0%. Run time:  31.87s. Est. time left: 00:00:00:13
# 80.0%. Run time:  36.73s. Est. time left: 00:00:00:09
# 90.0%. Run time:  40.88s. Est. time left: 00:00:00:04
# 100.0%. Run time:  45.30s. Est. time left: 00:00:00:00
# Total run time:  45.53s
# 10.0%. Run time:   4.25s. Est. time left: 00:00:00:38
# 20.0%. Run time:   8.60s. Est. time left: 00:00:00:34
# 30.0%. Run time:  12.91s. Est. time left: 00:00:00:30
# 40.0%. Run time:  17.18s. Est. time left: 00:00:00:25
# 50.0%. Run time:  21.63s. Est. time left: 00:00:00:21
# 60.0%. Run time:  26.11s. Est. time left: 00:00:00:17
# 70.0%. Run time:  33.47s. Est. time left: 00:00:00:14
# 80.0%. Run time:  38.43s. Est. time left: 00:00:00:09
# 90.0%. Run time:  43.43s. Est. time left: 00:00:00:04
# 100.0%. Run time:  48.84s. Est. time left: 00:00:00:00
# Total run time:  49.13s
# 10.0%. Run time:   4.85s. Est. time left: 00:00:00:43
# 20.0%. Run time:   9.83s. Est. time left: 00:00:00:39
# 30.0%. Run time:  14.95s. Est. time left: 00:00:00:34
# 40.0%. Run time:  19.95s. Est. time left: 00:00:00:29
# 50.0%. Run time:  24.54s. Est. time left: 00:00:00:24
# 60.0%. Run time:  29.51s. Est. time left: 00:00:00:19
# 70.0%. Run time:  34.29s. Est. time left: 00:00:00:14
# 80.0%. Run time:  38.44s. Est. time left: 00:00:00:09
# 90.0%. Run time:  43.20s. Est. time left: 00:00:00:04
# 100.0%. Run time:  47.64s. Est. time left: 00:00:00:00
# Total run time:  47.88s
# 10.0%. Run time:   4.55s. Est. time left: 00:00:00:40
# 20.0%. Run time:  10.31s. Est. time left: 00:00:00:41
# 30.0%. Run time:  15.05s. Est. time left: 00:00:00:35
# 40.0%. Run time:  19.61s. Est. time left: 00:00:00:29
# 50.0%. Run time:  24.67s. Est. time left: 00:00:00:24
# 60.0%. Run time:  29.85s. Est. time left: 00:00:00:19
# 70.0%. Run time:  34.92s. Est. time left: 00:00:00:14
# 80.0%. Run time:  39.64s. Est. time left: 00:00:00:09
# 90.0%. Run time:  44.18s. Est. time left: 00:00:00:04
# 100.0%. Run time:  49.52s. Est. time left: 00:00:00:00
# Total run time:  49.76s
# 10.0%. Run time:   4.43s. Est. time left: 00:00:00:39
# 20.0%. Run time:   8.95s. Est. time left: 00:00:00:35
# 30.0%. Run time:  13.42s. Est. time left: 00:00:00:31
# 40.0%. Run time:  17.62s. Est. time left: 00:00:00:26
# 50.0%. Run time:  21.83s. Est. time left: 00:00:00:21
# 60.0%. Run time:  26.11s. Est. time left: 00:00:00:17
# 70.0%. Run time:  30.38s. Est. time left: 00:00:00:13
# 80.0%. Run time:  34.64s. Est. time left: 00:00:00:08
# 90.0%. Run time:  39.02s. Est. time left: 00:00:00:04
# 100.0%. Run time:  44.68s. Est. time left: 00:00:00:00
# Total run time:  44.91s
# 10.0%. Run time:   4.26s. Est. time left: 00:00:00:38
# 20.0%. Run time:   9.79s. Est. time left: 00:00:00:39
# 30.0%. Run time:  15.14s. Est. time left: 00:00:00:35
# 40.0%. Run time:  19.32s. Est. time left: 00:00:00:28
# 50.0%. Run time:  23.73s. Est. time left: 00:00:00:23
# 60.0%. Run time:  28.17s. Est. time left: 00:00:00:18
# 70.0%. Run time:  32.51s. Est. time left: 00:00:00:13
# 80.0%. Run time:  36.60s. Est. time left: 00:00:00:09
# 90.0%. Run time:  40.40s. Est. time left: 00:00:00:04
# 100.0%. Run time:  44.33s. Est. time left: 00:00:00:00
# Total run time:  44.53s
# 10.0%. Run time:   3.94s. Est. time left: 00:00:00:35
# 20.0%. Run time:   7.83s. Est. time left: 00:00:00:31
# 30.0%. Run time:  12.61s. Est. time left: 00:00:00:29
# 40.0%. Run time:  16.83s. Est. time left: 00:00:00:25
# 50.0%. Run time:  20.92s. Est. time left: 00:00:00:20
# 60.0%. Run time:  24.71s. Est. time left: 00:00:00:16
# 70.0%. Run time:  28.59s. Est. time left: 00:00:00:12
# 80.0%. Run time:  32.49s. Est. time left: 00:00:00:08
# 90.0%. Run time:  36.30s. Est. time left: 00:00:00:04
# 100.0%. Run time:  40.31s. Est. time left: 00:00:00:00
# Total run time:  40.50s
# 10.0%. Run time:   3.76s. Est. time left: 00:00:00:33
# 20.0%. Run time:   7.57s. Est. time left: 00:00:00:30
# 30.0%. Run time:  11.51s. Est. time left: 00:00:00:26
# 40.0%. Run time:  15.52s. Est. time left: 00:00:00:23
# 50.0%. Run time:  19.33s. Est. time left: 00:00:00:19
# 60.0%. Run time:  23.99s. Est. time left: 00:00:00:15
# 70.0%. Run time:  28.61s. Est. time left: 00:00:00:12
# 80.0%. Run time:  33.73s. Est. time left: 00:00:00:08
# 90.0%. Run time:  37.58s. Est. time left: 00:00:00:04
# 100.0%. Run time:  41.52s. Est. time left: 00:00:00:00
# Total run time:  41.69s
# 10.0%. Run time:   3.86s. Est. time left: 00:00:00:34
# 20.0%. Run time:   8.06s. Est. time left: 00:00:00:32
# 30.0%. Run time:  12.17s. Est. time left: 00:00:00:28
# 40.0%. Run time:  16.46s. Est. time left: 00:00:00:24
# 50.0%. Run time:  20.37s. Est. time left: 00:00:00:20
# 60.0%. Run time:  25.20s. Est. time left: 00:00:00:16
# 70.0%. Run time:  29.32s. Est. time left: 00:00:00:12
# 80.0%. Run time:  33.48s. Est. time left: 00:00:00:08
# 90.0%. Run time:  37.80s. Est. time left: 00:00:00:04
# 100.0%. Run time:  41.61s. Est. time left: 00:00:00:00
# Total run time:  41.79s
# 10.0%. Run time:   3.84s. Est. time left: 00:00:00:34
# 20.0%. Run time:   8.18s. Est. time left: 00:00:00:32
# 30.0%. Run time:  13.13s. Est. time left: 00:00:00:30
# 40.0%. Run time:  17.06s. Est. time left: 00:00:00:25
# 50.0%. Run time:  21.10s. Est. time left: 00:00:00:21
# 60.0%. Run time:  24.95s. Est. time left: 00:00:00:16
# 70.0%. Run time:  29.20s. Est. time left: 00:00:00:12
# 80.0%. Run time:  33.38s. Est. time left: 00:00:00:08
# 90.0%. Run time:  37.58s. Est. time left: 00:00:00:04
# 100.0%. Run time:  41.64s. Est. time left: 00:00:00:00
# Total run time:  41.83s
# 10.0%. Run time:   3.65s. Est. time left: 00:00:00:32
# 20.0%. Run time:   7.48s. Est. time left: 00:00:00:29
# 30.0%. Run time:  11.24s. Est. time left: 00:00:00:26
# 40.0%. Run time:  15.10s. Est. time left: 00:00:00:22
# 50.0%. Run time:  19.33s. Est. time left: 00:00:00:19
# 60.0%. Run time:  23.62s. Est. time left: 00:00:00:15
# 70.0%. Run time:  27.91s. Est. time left: 00:00:00:11
# 80.0%. Run time:  32.25s. Est. time left: 00:00:00:08
# 90.0%. Run time:  36.19s. Est. time left: 00:00:00:04
# 100.0%. Run time:  40.11s. Est. time left: 00:00:00:00
# Total run time:  40.29s
# 10.0%. Run time:   4.20s. Est. time left: 00:00:00:37
# 20.0%. Run time:   8.52s. Est. time left: 00:00:00:34
# 30.0%. Run time:  12.62s. Est. time left: 00:00:00:29
# 40.0%. Run time:  16.80s. Est. time left: 00:00:00:25
# 50.0%. Run time:  20.89s. Est. time left: 00:00:00:20
# 60.0%. Run time:  24.90s. Est. time left: 00:00:00:16
# 70.0%. Run time:  29.13s. Est. time left: 00:00:00:12
# 80.0%. Run time:  33.23s. Est. time left: 00:00:00:08
# 90.0%. Run time:  37.38s. Est. time left: 00:00:00:04
# 100.0%. Run time:  41.19s. Est. time left: 00:00:00:00
# Total run time:  41.42s
# 10.0%. Run time:   3.93s. Est. time left: 00:00:00:35
# 20.0%. Run time:   7.76s. Est. time left: 00:00:00:31
# 30.0%. Run time:  11.71s. Est. time left: 00:00:00:27
# 40.0%. Run time:  15.62s. Est. time left: 00:00:00:23
# 50.0%. Run time:  19.44s. Est. time left: 00:00:00:19
# 60.0%. Run time:  23.19s. Est. time left: 00:00:00:15
# 70.0%. Run time:  26.76s. Est. time left: 00:00:00:11
# 80.0%. Run time:  30.34s. Est. time left: 00:00:00:07
# 90.0%. Run time:  34.10s. Est. time left: 00:00:00:03
# 100.0%. Run time:  37.79s. Est. time left: 00:00:00:00
# Total run time:  37.98s
# 10.0%. Run time:   3.68s. Est. time left: 00:00:00:33
# 20.0%. Run time:   7.56s. Est. time left: 00:00:00:30
# 30.0%. Run time:  11.51s. Est. time left: 00:00:00:26
# 40.0%. Run time:  15.43s. Est. time left: 00:00:00:23
# 50.0%. Run time:  19.38s. Est. time left: 00:00:00:19
# 60.0%. Run time:  23.36s. Est. time left: 00:00:00:15
# 70.0%. Run time:  27.22s. Est. time left: 00:00:00:11
# 80.0%. Run time:  31.04s. Est. time left: 00:00:00:07
# 90.0%. Run time:  34.72s. Est. time left: 00:00:00:03
# 100.0%. Run time:  38.29s. Est. time left: 00:00:00:00
# Total run time:  38.48s
# 10.0%. Run time:   3.39s. Est. time left: 00:00:00:30
# 20.0%. Run time:   7.11s. Est. time left: 00:00:00:28
# 30.0%. Run time:  10.84s. Est. time left: 00:00:00:25
# 40.0%. Run time:  14.50s. Est. time left: 00:00:00:21
# 50.0%. Run time:  18.16s. Est. time left: 00:00:00:18
# 60.0%. Run time:  21.78s. Est. time left: 00:00:00:14
# 70.0%. Run time:  25.44s. Est. time left: 00:00:00:10
# 80.0%. Run time:  29.01s. Est. time left: 00:00:00:07
# 90.0%. Run time:  32.65s. Est. time left: 00:00:00:03
# 100.0%. Run time:  36.25s. Est. time left: 00:00:00:00
# Total run time:  36.44s
# 10.0%. Run time:   3.39s. Est. time left: 00:00:00:30
# 20.0%. Run time:   7.05s. Est. time left: 00:00:00:28
# 30.0%. Run time:  11.20s. Est. time left: 00:00:00:26
# 40.0%. Run time:  15.16s. Est. time left: 00:00:00:22
# 50.0%. Run time:  18.72s. Est. time left: 00:00:00:18
# 60.0%. Run time:  22.31s. Est. time left: 00:00:00:14
# 70.0%. Run time:  25.97s. Est. time left: 00:00:00:11
# 80.0%. Run time:  29.62s. Est. time left: 00:00:00:07
# 90.0%. Run time:  33.24s. Est. time left: 00:00:00:03
# 100.0%. Run time:  36.90s. Est. time left: 00:00:00:00
# Total run time:  37.08s
# 10.0%. Run time:   3.44s. Est. time left: 00:00:00:30
# 20.0%. Run time:   7.32s. Est. time left: 00:00:00:29
# 30.0%. Run time:  12.03s. Est. time left: 00:00:00:28
# 40.0%. Run time:  18.19s. Est. time left: 00:00:00:27
# 50.0%. Run time:  24.32s. Est. time left: 00:00:00:24
# 60.0%. Run time:  29.48s. Est. time left: 00:00:00:19
# 70.0%. Run time:  33.74s. Est. time left: 00:00:00:14
# 80.0%. Run time:  37.83s. Est. time left: 00:00:00:09
# 90.0%. Run time:  41.69s. Est. time left: 00:00:00:04
# 100.0%. Run time:  46.17s. Est. time left: 00:00:00:00
# Total run time:  46.36s
# 10.0%. Run time:   4.23s. Est. time left: 00:00:00:38
# 20.0%. Run time:   8.48s. Est. time left: 00:00:00:33
# 30.0%. Run time:  12.49s. Est. time left: 00:00:00:29
# 40.0%. Run time:  16.62s. Est. time left: 00:00:00:24
# 50.0%. Run time:  20.88s. Est. time left: 00:00:00:20
# 60.0%. Run time:  24.73s. Est. time left: 00:00:00:16
# 70.0%. Run time:  28.94s. Est. time left: 00:00:00:12
# 80.0%. Run time:  32.97s. Est. time left: 00:00:00:08
# 90.0%. Run time:  36.84s. Est. time left: 00:00:00:04
# 100.0%. Run time:  40.81s. Est. time left: 00:00:00:00
# Total run time:  40.99s
